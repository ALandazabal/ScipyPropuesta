# %%
#CSV manage files
import csv
import xlsxwriter
#Provee un conjunto de estructuras para manipular datos
import pandas as pd
import string
import re #Regex

# %%
datos_excel = pd.read_excel(open('dbUniversidadesSinLinks.xlsx','rb'))
datos_excel = pd.DataFrame(datos_excel)
datos_excel.head()
# Out:
#                                                Tweet  Retweets  Favoritos  \
# 0  En estos 56 años como no detenernos a agradece...        17         31
# 1  Agradeciendo a Dios y otorgando la Orden 22 de...         5         12
# 2  RT @TraumaBqto: Porque más que enseñarme un of...         4          0
# 3  RT @mcuicasavila: @UCLAve Felicitaciones a nue...         3          0
# 4  RT @LenchoM: Que bueno cumplir año este #22sep...         3          0
#
#    Sentimiento
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
sample = datos_excel.sample(2193)
sample
# Out:
#                                                    Tweet  Retweets  Favoritos  \
# 5193   RT @fel_sanpol: Los niveles de exigencia, para...         5          0
# 3882   RT @UnefaAsobies: #EnVivo Ciudadano Rector Ner...        15          0
# 9057   Juramentada Comisión del Centro de Estudios Re...         1          3
# 4522   RT @NicolasMaduro: 115 años se cumplen del nat...      2315          0
# 11012  🔛 Núcleo Guayana: 📜Cronograma sobre el proceso...         7          0
# 11154  @Jh_Armas Buenas tardes! Debe dirigirse al lab...         0          0
# 11682  La Dirección de la Escuela de #Derecho de nues...         0          0
# 12633  Porque hacen falta abogados con un sólido sent...         2          3
# 8300   Esta información te interesa 👇\n.\nEgresados d...        12         12
# 14916  ¡Síguenos en nuestra cuenta oficial de Instagr...         1          6
# 14476  Los trámites de preinscripción, reincorporació...         0          1
# ...

# %%
libro = xlsxwriter.Workbook('dbUniversidadesXEtiquetar.xlsx')
hoja = libro.add_worksheet('Data')

#myFile = open('dbUniversidades.csv', 'w')
data = ["Tweet", "Retweets", "Favoritos","Sentimiento"]
row = 0
col = 0
 
# Iteramos los datos para ir pintando los encabezados
for titulo in data:
    hoja.write(row, col, titulo)
    col += 1
row = 1
col = 0

for indice_fila, fila in sample.iterrows():
    hoja.write(row, 0, fila[0])
    hoja.write(row, 1, fila[1])
    hoja.write(row, 2, fila[2])
    row += 1;
libro.close()

# %%
len(sample)
# Out:
# 2193

# %%
libro2 = xlsxwriter.Workbook('dbUniversidadesSinLinks2.xlsx')
hoja2 = libro2.add_worksheet('Data')

#myFile = open('dbUniversidades.csv', 'w')
data = ["Tweet", "Retweets", "Favoritos","Sentimiento"]
row = 0
col = 0
 
# Iteramos los datos para ir pintando los encabezados
for titulo in data:
    hoja2.write(row, col, titulo)
    col += 1
row = 1
col = 0

# sorting data frame by name 
sampleSort = sample.sort_index()

for indice_fila, fila in datos_excel.iterrows():
    
    for indice_filaS, filaS in sampleSort.iterrows():
        if fila[0] == filaS[0]:
    hoja2.write(row, 0, fila[0])
    hoja2.write(row, 1, fila[1])
    hoja2.write(row, 2, fila[2])
    row += 1;
libro2.close()
sampleSort
# Out:
#                                                    Tweet  Retweets  Favoritos  \
# 19     RT @Conser_VES: La Fundación Conservatorio Vic...         8          0
# 21     RT @OBUniversidades: Felicidades a la @UCLAve ...         4          0
# 25     RT @ASOPORTUGUESA: La Universidad Centrocciden...        53          0
# 37     RT @CaraotaDigital: Subastarán ganado en la #U...        19          0
# 41     Hoy #19Sep, a las 10am, en el auditorio Ambros...         5          5
# 49     La Caja de Ahorro y Préstamo de los Profesores...         2          0
# 52         @sorayamachkouk @nvelasquezmago ¿Qué carrera?         0          0
# 57     @josealfredoval6 Debes dirigirte a Control de ...         0          0
# 65     En el transcurso de la tarde se consultó con e...         7          5
# 73     La Rectora @nvelasquezmago ratifica a la comun...        33         35
# 77     DICORI contribuye con posicionamiento de la UC...         8         10
# ...

# %%
datos_excel = pd.read_excel(open('dbUniversidadesXEtiquetar.xlsx','rb'))
datos_excel = pd.DataFrame(datos_excel)
datos_excel.head()
# Out:
#                                                Tweet  Retweets  Favoritos  \
# 0  RT @fel_sanpol: Los niveles de exigencia, para...         5          0
# 1  RT @UnefaAsobies: #EnVivo Ciudadano Rector Ner...        15          0
# 2  Juramentada Comisión del Centro de Estudios Re...         1          3
# 3  RT @NicolasMaduro: 115 años se cumplen del nat...      2315          0
# 4  🔛 Núcleo Guayana: 📜Cronograma sobre el proceso...         7          0
#
#   Sentimiento
# 0         neu
# 1         pos
# 2         pos
# 3         pos
# 4         neu

# %%
datos_excelSinLinks = pd.read_excel(open('dbUniversidadesSinLinks.xlsx','rb'))
datos_excelSinLinks = pd.DataFrame(datos_excelSinLinks)
datos_excelSinLinks.head()
# Out:
#                                                Tweet  Retweets  Favoritos  \
# 0  En estos 56 años como no detenernos a agradece...        17         31
# 1  Agradeciendo a Dios y otorgando la Orden 22 de...         5         12
# 2  RT @TraumaBqto: Porque más que enseñarme un of...         4          0
# 3  RT @mcuicasavila: @UCLAve Felicitaciones a nue...         3          0
# 4  RT @LenchoM: Que bueno cumplir año este #22sep...         3          0
#
#    Sentimiento
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
libro2 = xlsxwriter.Workbook('dbUniversidadesSinEtiquetar.xlsx')
hoja2 = libro2.add_worksheet('Data')

#myFile = open('dbUniversidades.csv', 'w')
data = ["Tweet", "Retweets", "Favoritos","Sentimiento"]
row = 0
col = 0
 
# Iteramos los datos para ir pintando los encabezados
for titulo in data:
    hoja2.write(row, col, titulo)
    col += 1
row = 1
col = 0

for indice_fila, fila in datos_excelSinLinks.iterrows():
    if indice_fila > 18:
        band = 0
        for indice_filaE, filaE in datos_excel.iterrows():
            if fila[0] == filaE[0]:
                #print(fila[0])
                band = 1
                break

        if band == 0:
            hoja2.write(row, 0, fila[0])
            hoja2.write(row, 1, fila[1])
            hoja2.write(row, 2, fila[2])
            
            print(fila[0])
            row += 1

        '''if row == 28:
            break'''
    #hoja2.set_row(indice_filaS+2, None, None, {'hidden': True})
libro2.close()
# Out:
# RT @AncaDigital: Son 56 años al servicio de centroccidente, formando profesionales de valor,  trayectoria que hoy la convierten en la prime…
# RT @Radiominuto790: @UCLAve 56 años dando la bienvenida a la esperanza de miles y miles de jóvenes que quieren un mejor futuro para ellos,…
# RT @martha_astral: @UCLAve Hoy de aniversario nuestra amada universidad, la UCLA...56 años siendo: La voz del pensamiento y la excelencia a…
# RT @lusolarenseac: Van 56 años dando la bienvenida a la esperanza de miles y miles de jóvenes que quieren un mejor futuro para ellos, su fa…
# RT @miguel_e_: Que lindura orgulloso de ser Uclaista https://t.co/ndDo3oX5mL
# RT @PepitaMontero: @UCLAve. Muy feliz aniversario que sea su recinto fortaleza para todos los que comprenden la importancia de la formación…
# RT @martha_astral: @UCLAve Yo ♥ UCLA https://t.co/w7r9bGa5L0
# RT @Mailenycr: Felicidades a mi amada @UCLAve @UCLADCyT https://t.co/37vUIqudmy
# ...
